# %%
#import
import pandas as pd
import matplotlib.pyplot as mt

# %%
#read data
df = pd.read_excel('dataset.xlsx')
#check data length
len(df)
# Out:
# 20000

# %%
#print data head
df.head()
# Out:
#       ID  cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0  12554  20014.0     24893.00       378.00     10288.00     29664.00
# 1  17645  10173.0     18941.62       966.00     20672.00       287.00
# 2   7604  16095.0      5678.87      2724.00      1964.50      3933.11
# 3   1590   7707.0     30489.50      1236.00     12609.88      9138.14
# 4  16556  96408.0      7441.40      6906.04      4364.00      1939.00
#
#    cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  \
# 0     16291.40     11432.00           2.0            26  ...
# 1      4217.00       885.00           1.0             7  ...
# 2     23956.25      5168.00          43.0            32  ...
# 3     17521.00     13650.30          53.0             1  ...
# 4      2121.00      6829.18          67.0            47  ...
#
#    credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0            12761.0                 2               65
# 1            76206.0                21               63
# 2            75283.0                 7                1
# 3            68708.0                21               83
# 4            80140.0                 8               32
#
#    max_credit_amount_jun  loan_enq  emi_active  account_type  gender  age  \
# 0                50836.0         Y     1674.09       current       M   35
# 1                23226.0         Y    13043.34       current       M   35
# 2                27036.0         Y    25375.27       current       M   55
# 3                43037.0         Y     3544.33       current       F   29
# 4                32044.0       NaN    12780.44       current       M   34
#
#    region_code
# 0        708.0
# 1        123.0
# 2        802.0
# 3        867.0
# 4        802.0
#
# [5 rows x 44 columns]

# %%
# Check for null values
df.isnull().sum()
# Out:
# ID                          0
# cc_cons                  5000
# cc_cons_apr                 0
# dc_cons_apr                 0
# cc_cons_may                 1
# dc_cons_may                 0
# cc_cons_jun                 0
# dc_cons_jun                 1
# cc_count_apr                1
# cc_count_may                0
# cc_count_jun                0
# dc_count_apr                0
# dc_count_may                0
# dc_count_jun                0
# card_lim                    0
# personal_loan_active        0
# vehicle_loan_active         0
# personal_loan_closed        1
# vehicle_loan_closed         0
# investment_1                0
# investment_2                0
# investment_3                2
# investment_4                0
# debit_amount_apr            0
# credit_amount_apr           0
# debit_count_apr             1
# credit_count_apr            0
# max_credit_amount_apr       0
# debit_amount_may            0
# credit_amount_may           0
# credit_count_may            0
# debit_count_may             0
# max_credit_amount_may       0
# debit_amount_jun            0
# credit_amount_jun           0
# credit_count_jun            0
# debit_count_jun             0
# max_credit_amount_jun       0
# loan_enq                    2
# emi_active                  1
# account_type                1
# gender                      1
# age                         0
# region_code                 1
# dtype: int64

# %%
# drop rows with missing values
df = df.dropna(subset=['cc_cons_may', 'dc_cons_jun', 'cc_count_apr', 'personal_loan_closed', 'investment_3', 'debit_count_apr', 'loan_enq', 'emi_active', 'account_type', 'gender', 'region_code'])

# %%
len(df)
# Out:
# 19991

# %%
# Check for null values
df.isnull().sum()
# Out:
# ID                          0
# cc_cons                  4996
# cc_cons_apr                 0
# dc_cons_apr                 0
# cc_cons_may                 0
# dc_cons_may                 0
# cc_cons_jun                 0
# dc_cons_jun                 0
# cc_count_apr                0
# cc_count_may                0
# cc_count_jun                0
# dc_count_apr                0
# dc_count_may                0
# dc_count_jun                0
# card_lim                    0
# personal_loan_active        0
# vehicle_loan_active         0
# personal_loan_closed        0
# vehicle_loan_closed         0
# investment_1                0
# investment_2                0
# investment_3                0
# investment_4                0
# debit_amount_apr            0
# credit_amount_apr           0
# debit_count_apr             0
# credit_count_apr            0
# max_credit_amount_apr       0
# debit_amount_may            0
# credit_amount_may           0
# credit_count_may            0
# debit_count_may             0
# max_credit_amount_may       0
# debit_amount_jun            0
# credit_amount_jun           0
# credit_count_jun            0
# debit_count_jun             0
# max_credit_amount_jun       0
# loan_enq                    0
# emi_active                  0
# account_type                0
# gender                      0
# age                         0
# region_code                 0
# dtype: int64

# %%
# check percentage of missing values
df.duplicated().sum()
# Out:
# 0

# %%
# check data types of columns
df.dtypes
# Out:
# ID                         int64
# cc_cons                  float64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr             float64
# cc_count_may               int64
# cc_count_jun               int64
# dc_count_apr               int64
# dc_count_may               int64
# dc_count_jun               int64
# card_lim                   int64
# personal_loan_active       int64
# vehicle_loan_active        int64
# personal_loan_closed     float64
# vehicle_loan_closed        int64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# debit_count_apr          float64
# credit_count_apr           int64
# max_credit_amount_apr    float64
# debit_amount_may         float64
# credit_amount_may        float64
# credit_count_may           int64
# debit_count_may            int64
# max_credit_amount_may    float64
# debit_amount_jun         float64
# credit_amount_jun        float64
# credit_count_jun           int64
# debit_count_jun            int64
# max_credit_amount_jun    float64
# loan_enq                  object
# emi_active               float64
# account_type              object
# gender                    object
# age                        int64
# region_code              float64
# dtype: object

# %%
# convert data types to the correct format
convert_dict = {
    'cc_count_apr': int,
    'personal_loan_closed': int,
    'debit_count_apr': int,
}
df = df.astype(convert_dict)

# %%
# check data types of columns
df.dtypes
# Out:
# ID                         int64
# cc_cons                  float64
# cc_cons_apr              float64
# dc_cons_apr              float64
# cc_cons_may              float64
# dc_cons_may              float64
# cc_cons_jun              float64
# dc_cons_jun              float64
# cc_count_apr               int32
# cc_count_may               int64
# cc_count_jun               int64
# dc_count_apr               int64
# dc_count_may               int64
# dc_count_jun               int64
# card_lim                   int64
# personal_loan_active       int64
# vehicle_loan_active        int64
# personal_loan_closed       int32
# vehicle_loan_closed        int64
# investment_1             float64
# investment_2             float64
# investment_3             float64
# investment_4             float64
# debit_amount_apr         float64
# credit_amount_apr        float64
# debit_count_apr            int32
# credit_count_apr           int64
# max_credit_amount_apr    float64
# debit_amount_may         float64
# credit_amount_may        float64
# credit_count_may           int64
# debit_count_may            int64
# max_credit_amount_may    float64
# debit_amount_jun         float64
# credit_amount_jun        float64
# credit_count_jun           int64
# debit_count_jun            int64
# max_credit_amount_jun    float64
# loan_enq                  object
# emi_active               float64
# account_type              object
# gender                    object
# age                        int64
# region_code              float64
# dtype: object

# %%
# check for negative values (outliers)
df._get_numeric_data().lt(0).sum()
# Out:
# ID                          0
# cc_cons                     0
# cc_cons_apr                 0
# dc_cons_apr                 0
# cc_cons_may                 0
# dc_cons_may                 0
# cc_cons_jun                 0
# dc_cons_jun                 0
# cc_count_apr                0
# cc_count_may                0
# cc_count_jun                0
# dc_count_apr                0
# dc_count_may                0
# dc_count_jun                0
# card_lim                    0
# personal_loan_active        0
# vehicle_loan_active         0
# personal_loan_closed        0
# vehicle_loan_closed         0
# investment_1                0
# investment_2                0
# investment_3                0
# investment_4             4331
# debit_amount_apr            0
# credit_amount_apr           0
# debit_count_apr             0
# credit_count_apr            0
# max_credit_amount_apr       0
# debit_amount_may            0
# credit_amount_may           0
# credit_count_may            0
# debit_count_may             0
# max_credit_amount_may       0
# debit_amount_jun            0
# credit_amount_jun           0
# credit_count_jun            0
# debit_count_jun             0
# max_credit_amount_jun       0
# emi_active                  0
# age                         0
# region_code                 0
# dtype: int64

# %%
# set negative values to 0
for x in df.index:
    if df.loc[x, 'investment_4'] < 0:
        df.loc[x, 'investment_4'] = 0

# %%
# check for negative values (outliers)
df._get_numeric_data().lt(0).sum()
# Out:
# ID                       0
# cc_cons                  0
# cc_cons_apr              0
# dc_cons_apr              0
# cc_cons_may              0
# dc_cons_may              0
# cc_cons_jun              0
# dc_cons_jun              0
# cc_count_apr             0
# cc_count_may             0
# cc_count_jun             0
# dc_count_apr             0
# dc_count_may             0
# dc_count_jun             0
# card_lim                 0
# personal_loan_active     0
# vehicle_loan_active      0
# personal_loan_closed     0
# vehicle_loan_closed      0
# investment_1             0
# investment_2             0
# investment_3             0
# investment_4             0
# debit_amount_apr         0
# credit_amount_apr        0
# debit_count_apr          0
# credit_count_apr         0
# max_credit_amount_apr    0
# debit_amount_may         0
# credit_amount_may        0
# credit_count_may         0
# debit_count_may          0
# max_credit_amount_may    0
# debit_amount_jun         0
# credit_amount_jun        0
# credit_count_jun         0
# debit_count_jun          0
# max_credit_amount_jun    0
# emi_active               0
# age                      0
# region_code              0
# dtype: int64

# %%
import plotly.express as px
fig = px.box(df, y="age")

fig.show()

# %%
df.loc[df['age']>75,'age'] = df['age'].median()

# %%
#split dataset into train and test
#get data with not null cc_cons as train data
train_df = df[df['cc_cons'].notnull()]
#get data with null cc_cons as test data
test_df = df[df['cc_cons'].isnull()]

# %%
train_df
# Out:
#           ID   cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0      12554   20014.0     24893.00       378.00     10288.00     29664.00
# 1      17645   10173.0     18941.62       966.00     20672.00       287.00
# 2       7604   16095.0      5678.87      2724.00      1964.50      3933.11
# 3       1590    7707.0     30489.50      1236.00     12609.88      9138.14
# 5      19106  130263.0      2328.22      1597.54     19979.75      1045.85
# ...      ...       ...          ...          ...          ...          ...
# 14995   6995    4263.0     10443.76      1218.85      7252.24      3873.00
# 14996  10376   11019.0     29890.33      6308.00     16025.50      7610.00
# 14997   2181  404227.0      4148.98       948.74     19360.26       494.00
# 14998  18417   28813.0    115574.00      7191.05     44341.13     34817.20
# 14999   4547   16252.0      7375.67       306.80      5859.49      6702.40
#
#        cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  \
# 0        16291.400     11432.00             2            26  ...
# 1         4217.000       885.00             1             7  ...
# 2        23956.250      5168.00            43            32  ...
# 3        17521.000     13650.30            53             1  ...
# 5        11686.255       628.00             6             7  ...
# ...            ...          ...           ...           ...  ...
# 14995     6633.000     10107.00             3            36  ...
# 14996     2213.080       841.60             1            34  ...
# 14997    44363.910      1801.77            57            23  ...
# 14998    20679.000      1010.00             7           128  ...
# 14999    33211.650       263.00            28            71  ...
#
#        credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0               12761.00                 2               65
# 1               76206.00                21               63
# 2               75283.00                 7                1
# 3               68708.00                21               83
# 5              199925.50                 2               35
# ...                  ...               ...              ...
# 14995           42625.50                14                8
# 14996           34987.55                11               18
# 14997          261432.00                 4               73
# 14998           33025.29                 3               80
# 14999           78574.00                47               50
#
#        max_credit_amount_jun  loan_enq  emi_active  account_type  gender  age  \
# 0                   50836.00         Y     1674.09       current       M   35
# 1                   23226.00         Y    13043.34       current       M   35
# 2                   27036.00         Y    25375.27       current       M   55
# 3                   43037.00         Y     3544.33       current       F   29
# 5                   17284.00         Y     5026.50       current       M   27
# ...                      ...       ...         ...           ...     ...  ...
# 14995               82851.00         Y    78966.76       current       F   53
# 14996              118110.47         Y     4762.10       current       M   44
# 14997               49545.00         Y     2877.33       current       M   37
# 14998               16130.00         Y    13006.84       current       M   40
# 14999               22849.00         Y     1588.60       current       M   66
#
#        region_code
# 0            708.0
# 1            123.0
# 2            802.0
# 3            867.0
# 5            958.0
# ...            ...
# 14995        653.0
# 14996        535.0
# 14997        464.0
# 14998        536.0
# 14999        269.0
#
# [14995 rows x 44 columns]

# %%
test_df
# Out:
#           ID  cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 15000  17591      NaN     2795.450      1290.00      6141.05       676.50
# 15001  13541      NaN    29405.130      1640.00      1670.00      2463.92
# 15002  13431      NaN     5985.200      6189.00      2696.09       766.00
# 15003   8687      NaN     2105.930     18225.00     34763.56       167.00
# 15004  14727      NaN     3269.000      3532.00      3158.40      2699.77
# ...      ...      ...          ...          ...          ...          ...
# 19995  12512      NaN     4641.500      5979.58      6008.61      4410.00
# 19996  14224      NaN     4994.450      2805.37     23214.00      5870.00
# 19997  18740      NaN     3262.145      2871.00      7335.25     11774.04
# 19998  18134      NaN    12824.010      4866.00     12242.48       284.00
# 19999  12413      NaN    26218.000      6615.00      2832.00      4642.00
#
#        cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  \
# 15000      9146.10     15479.00             4            10  ...
# 15001     10947.50       956.00             3            10  ...
# 15002       716.00      4133.22             7            30  ...
# 15003      4260.27     20185.00             1            99  ...
# 15004      3373.48      5120.00             2            10  ...
# ...            ...          ...           ...           ...  ...
# 19995     41743.00      1884.00            26             1  ...
# 19996      1041.00      1008.73            37            56  ...
# 19997      4130.00      1413.00            12            77  ...
# 19998     15132.77     37911.00            67             1  ...
# 19999      1314.64     11355.00             7             1  ...
#
#        credit_amount_jun  credit_count_jun  debit_count_jun  \
# 15000           31271.00                 3               12
# 15001           16582.00                 6               39
# 15002           33539.54                 5                9
# 15003          109429.75                21                0
# 15004           41401.00                 6               35
# ...                  ...               ...              ...
# 19995          125470.83                21               50
# 19996           86559.00                62               38
# 19997           80627.00                 2               18
# 19998           24332.00               117               64
# 19999           76669.00                 9               64
#
#        max_credit_amount_jun  loan_enq  emi_active  account_type  gender  age  \
# 15000               25945.92         Y     1170.49       current       M   37
# 15001               12214.00         Y    16447.45       current       M   33
# 15002               13215.00         Y     2622.28       current       M   53
# 15003               72317.00         Y      340.79       current       M   33
# 15004               42344.00         Y     2812.20       current       M   62
# ...                      ...       ...         ...           ...     ...  ...
# 19995               58037.00         Y     7870.88       current       M   35
# 19996               24110.00         Y     3668.30       current       M   53
# 19997                1769.00         Y     5450.34       current       M   62
# 19998               37255.00         Y       59.29       current       M   34
# 19999               96213.00         Y      793.41       current       M   27
#
#        region_code
# 15000        575.0
# 15001        394.0
# 15002        324.0
# 15003        370.0
# 15004        505.0
# ...            ...
# 19995        523.0
# 19996        723.0
# 19997        863.0
# 19998        882.0
# 19999        447.0
#
# [4996 rows x 44 columns]

# %%
train_df.isnull().sum()
# Out:
# ID                       0
# cc_cons                  0
# cc_cons_apr              0
# dc_cons_apr              0
# cc_cons_may              0
# dc_cons_may              0
# cc_cons_jun              0
# dc_cons_jun              0
# cc_count_apr             0
# cc_count_may             0
# cc_count_jun             0
# dc_count_apr             0
# dc_count_may             0
# dc_count_jun             0
# card_lim                 0
# personal_loan_active     0
# vehicle_loan_active      0
# personal_loan_closed     0
# vehicle_loan_closed      0
# investment_1             0
# investment_2             0
# investment_3             0
# investment_4             0
# debit_amount_apr         0
# credit_amount_apr        0
# debit_count_apr          0
# credit_count_apr         0
# max_credit_amount_apr    0
# debit_amount_may         0
# credit_amount_may        0
# credit_count_may         0
# debit_count_may          0
# max_credit_amount_may    0
# debit_amount_jun         0
# credit_amount_jun        0
# credit_count_jun         0
# debit_count_jun          0
# max_credit_amount_jun    0
# loan_enq                 0
# emi_active               0
# account_type             0
# gender                   0
# age                      0
# region_code              0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# ID                          0
# cc_cons                  4996
# cc_cons_apr                 0
# dc_cons_apr                 0
# cc_cons_may                 0
# dc_cons_may                 0
# cc_cons_jun                 0
# dc_cons_jun                 0
# cc_count_apr                0
# cc_count_may                0
# cc_count_jun                0
# dc_count_apr                0
# dc_count_may                0
# dc_count_jun                0
# card_lim                    0
# personal_loan_active        0
# vehicle_loan_active         0
# personal_loan_closed        0
# vehicle_loan_closed         0
# investment_1                0
# investment_2                0
# investment_3                0
# investment_4                0
# debit_amount_apr            0
# credit_amount_apr           0
# debit_count_apr             0
# credit_count_apr            0
# max_credit_amount_apr       0
# debit_amount_may            0
# credit_amount_may           0
# credit_count_may            0
# debit_count_may             0
# max_credit_amount_may       0
# debit_amount_jun            0
# credit_amount_jun           0
# credit_count_jun            0
# debit_count_jun             0
# max_credit_amount_jun       0
# loan_enq                    0
# emi_active                  0
# account_type                0
# gender                      0
# age                         0
# region_code                 0
# dtype: int64

# %%
# export train and test dataset to excel file
train_df.to_excel('train.xlsx', index=False)
test_df.to_excel('test.xlsx', index=False)
